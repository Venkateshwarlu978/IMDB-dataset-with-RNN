# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from tensorflow.keras.preprocessing.text import one_hot
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
sentences = ["I love this movie", "This film is bad"]
vocab_size = 50

encoded = [one_hot(s, vocab_size) for s in sentences]
print(encoded)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 sentences = ["I love this movie", "This film is bad"]
#       2 vocab_size = 50
# ----> 4 encoded = [one_hot(s, vocab_size) for s in sentences]
#       5 print(encoded)
#
# NameError: name 'one_hot' is not defined
